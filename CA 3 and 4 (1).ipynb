# %%
import pandas as pd
df=pd.read_csv(r'IndividualDetails.csv')

# %%
import matplotlib.pyplot as plt
labels = ['notes','detected_state','current_status','detected_city']
sizes = [100, 50,150,90]
colors = ['yellow', 'green','red','blue']
explode = (0,0, 0.2, 0) 
plt.title('No. of immigrants captured state and cities or recovery status')
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)
plt.axis('equal')

plt.show()

# %%
df.gender
df['gender']
df['gender'].value_counts()
# Out:
# M    351
# F    182
# Name: gender, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
dfplot=df[["age","gender","detected_state"]].dropna()
# Get names of indexes for which column Age has value 30
indexNames = dfplot[ dfplot['age'] == '28-35' ].index
 # Delete these row indexes from dataFrame
dfplot.drop(indexNames , inplace=True)
dfplot['age'] = pd.to_numeric(dfplot['age'])
sns.catplot(x= 'gender' ,y="age",hue='detected_state',data=dfplot)

# %%
import matplotlib.pyplot as plt

#clear the fig
plt.figure(figsize=(20,15))
countage=dfplot['age'].value_counts()
x_axis=np.arange(len(countage))
xt=list(countage.index)

plt.bar(x_axis,countage)
plt.xticks(x_axis,xt,rotation=90)
plt.xlabel("Ages")
plt.ylabel("Freq")
plt.title("No. of cases on different Ages")
plt.show()
